# %%
# We will use this package for our graph 
# !pip install jgraph
# Out:
# Collecting jgraph
#   Downloading jgraph-0.2.1-py2.py3-none-any.whl (119kB)
# Requirement already satisfied: ipython in c:\users\berk\anaconda3\lib\site-packages (from jgraph)
# Installing collected packages: jgraph
# Successfully installed jgraph-0.2.1

# %%
import jgraph

size = 4.9

graph = {
    'nodes': {
        'ross': {'color': 0xffaaaa, 'size': 2.0},
        'joey': {'size': 0.5},
        'chandler': {'color': 0x2222ff, 'size': size},
        'phoebe': {'color': 0x22ff22},
        'rachel': {},
        'monica': {},
        'jack': {},
        'judy': {},
    },
    'edges': [
        {'source': 'chandler', 'target': 'ross'},
        {'source': 'monica', 'target': 'ross'},
        {'source': 'ross', 'target': 'rachel', 'size': 3, 'color': 0xffaaaa},
        {'source': 'ross', 'target': 'joey'},
        {'source': 'ross', 'target': 'phoebe'},
        {'source': 'ross', 'target': 'judy'},
        {'source': 'monica', 'target': 'rachel'},
        {'source': 'rachel', 'target': 'jack'},
        {'source': 'chandler', 'target': 'phoebe'}
    ]
}

jgraph.draw(graph)
# Out:
# <div id="graph-8c51b28e-b365-4125-88ae-eefcd38fedc2"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                              paths: {jgraph: ['nbextensions/jgraph.min', 'https://rawgit.com/patrickfuller/jgraph/master/js/build/jgraph.min']}});
#            require(['jgraph'], function () {
#                var $d = $('#graph-8c51b28e-b365-4125-88ae-eefcd38fedc2');
#                $d.width(600); $d.height(400);
#                $d.jgraph = jQuery.extend({}, jgraph);
#                $d.jgraph.create($d, {nodeSize: 2.000000,
#                                      edgeSize: 0.250000,
#                                      defaultNodeColor: '0x5bc0de',
#                                      defaultEdgeColor: '0xaaaaaa',
#                                      shader: 'basic',
#                                      z: 100,
#                                      runOptimization: true,
#                                      directed: true,
#                                      showSave: false});
#                $d.jgraph.draw({
#     "edges": [
#         { "source": "chandler", "target": "ross" },
#         { "source": "monica", "target": "ross" },
#         { "color": "0xffaaaa", "size": 3, "source": "ross", "target": "rachel" },
#         { "source": "ross", "target": "joey" },
#         { "source": "ross", "target": "phoebe" },
#         { "source": "ross", "target": "judy" },
#         { "source": "monica", "target": "rachel" },
#         { "source": "rachel", "target": "jack" },
#         { "source": "chandler", "target": "phoebe" }
#     ],
#     "nodes": {
#         "chandler": { "color": "0x2222ff", "size": 4.9 },
#         "jack": {},
#         "joey": { "size": 0.5 },
#         "judy": {},
#         "monica": {},
#         "phoebe": { "color": "0x22ff22" },
#         "rachel": {},
#         "ross": { "color": "0xffaaaa", "size": 2.0 }
#     }
# });
#
#                $d.resizable({
#                    aspectRatio: 600 / 400,
#                    resize: function (evt, ui) {
#                        $d.jgraph.renderer.setSize(ui.size.width,
#                                                   ui.size.height);
#                    }
#                });
#            });
#            </script>

# %%
import json
from operator import itemgetter

with open('data0_50.json') as data_file:    
    data = json.load( data_file )

playtimes = []

for player in data:
    for server in player:
        
        if( server in ['eu', 'us', 'kr'] and player[server] and player[server]['heroes']['playtime']['competitive'] ):
            
            playtimes.append( sorted( player[server]['heroes']['playtime']['competitive'].items(), key=lambda v:v[1], reverse=True )[:3] )
            

print( len(playtimes) )
# Out:
# 101

# %%
graph = {
    'nodes': {
        'genji': {'color': 0xffaaaa, 'size': 2.0},
        'tracer': {'color': 0xffaaaa, 'size': 2.0},
        'reaper': {'color': 0xffaaaa, 'size': 2.0},
        'sombra': {'color': 0xffaaaa, 'size': 2.0},
        'mccree': {'color': 0xffaaaa, 'size': 2.0},
        'pharah': {'color': 0xffaaaa, 'size': 2.0},
        'soldier76': {'color': 0xffaaaa, 'size': 2.0},
        
        'hanzo': {'color': 0xAAFFAA, 'size': 2.0}, 
        'junkrat': {'color': 0xAAFFAA, 'size': 2.0},
        'mei': {'color': 0xAAFFAA, 'size': 2.0},
        'widowmaker': {'color': 0xAAFFAA, 'size': 2.0},
        'bastion': {'color': 0xAAFFAA, 'size': 2.0},
        'torbjorn': {'color': 0xAAFFAA, 'size': 2.0},
        
        'dva': {'color': 0x41F2B5, 'size': 2.0},
        'reinhardt': {'color': 0x41F2B5, 'size': 2.0},
        'orisa': {'color': 0x41F2B5, 'size': 2.0},
        'roadhog': {'color': 0x41F2B5, 'size': 2.0},
        'winston': {'color': 0x41F2B5, 'size': 2.0},
        'zarya': {'color': 0x41F2B5, 'size': 2.0},
        
        'lucio': {'color': 0x37D03A, 'size': 2.0},
        'mercy': {'color': 0x37D03A, 'size': 2.0},
        'zenyatta': {'color': 0x37D03A, 'size': 2.0},
        'symmetra': {'color': 0x37D03A, 'size': 2.0},
        'ana': {'color': 0x37D03A, 'size': 2.0},
    }
#         {'source': 'genji', 'target': 'hanzo', 'size': 3, 'color': 0x606ABE},
}

# %%
from collections import Counter

graph['edges'] = []
connections = []
#         {'source': 'genji', 'target': 'hanzo', 'size': 3, 'color': 0x606ABE},

def connect ( source, target ):
    if source > target:
        return ( source, target )
    else:
        return ( target, source )

for times in playtimes[:]:
    connections.append( connect( times[0][0], times[1][0] ) )
    connections.append( connect( times[1][0], times[2][0] ) )
    connections.append( connect( times[2][0], times[0][0] ) )

connections = dict( Counter(connections) )

print( connections )

for (s, t) in connections:
    if connections[(s,t)] > 30:
        graph['edges'].append( {'source': s, 'target': t, 'size': connections[(s,t)]-30} )

jgraph.draw(graph)

# print( json.dumps( graph, indent=3 ) )
# Out:
# {('tracer', 'soldier76'): 47, ('soldier76', 'roadhog'): 8, ('tracer', 'roadhog'): 6, ('genji', 'ana'): 4, ('widowmaker', 'genji'): 3, ('widowmaker', 'ana'): 5, ('zenyatta', 'mercy'): 2, ('zenyatta', 'ana'): 2, ('mercy', 'ana'): 4, ('soldier76', 'genji'): 31, ('tracer', 'genji'): 29, ('torbjorn', 'soldier76'): 1, ('tracer', 'torbjorn'): 1, ('soldier76', 'dva'): 2, ('genji', 'dva'): 2, ('mccree', 'genji'): 11, ('reinhardt', 'mccree'): 1, ('reinhardt', 'genji'): 1, ('tracer', 'mccree'): 17, ('reaper', 'mccree'): 3, ('tracer', 'reaper'): 2, ('soldier76', 'mccree'): 20, ('zarya', 'roadhog'): 6, ('zarya', 'soldier76'): 10, ('soldier76', 'ana'): 4, ('mccree', 'ana'): 1, ('zarya', 'mccree'): 3, ('winston', 'soldier76'): 2, ('zarya', 'winston'): 6, ('widowmaker', 'soldier76'): 1, ('widowmaker', 'tracer'): 1, ('mei', 'genji'): 2, ('tracer', 'mei'): 2, ('roadhog', 'genji'): 2, ('zarya', 'ana'): 3, ('zarya', 'genji'): 3, ('roadhog', 'reaper'): 1, ('roadhog', 'pharah'): 3, ('reaper', 'pharah'): 1, ('zarya', 'reinhardt'): 1, ('soldier76', 'reinhardt'): 1, ('roadhog', 'ana'): 2, ('widowmaker', 'roadhog'): 2, ('zenyatta', 'tracer'): 1, ('zenyatta', 'soldier76'): 1, ('tracer', 'ana'): 3, ('zarya', 'tracer'): 5, ('winston', 'roadhog'): 7, ('soldier76', 'mercy'): 2, ('pharah', 'genji'): 3, ('zarya', 'dva'): 2, ('pharah', 'dva'): 1, ('zarya', 'pharah'): 1, ('sombra', 'pharah'): 1, ('sombra', 'roadhog'): 1, ('tracer', 'pharah'): 2, ('winston', 'reinhardt'): 3, ('roadhog', 'reinhardt'): 3, ('reaper', 'genji'): 1, ('roadhog', 'dva'): 3, ('lucio', 'dva'): 2, ('roadhog', 'lucio'): 2}
# <div id="graph-125a519e-d21e-47a1-b017-80494b12af23"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                              paths: {jgraph: ['nbextensions/jgraph.min', 'https://rawgit.com/patrickfuller/jgraph/master/js/build/jgraph.min']}});
#            require(['jgraph'], function () {
#                var $d = $('#graph-125a519e-d21e-47a1-b017-80494b12af23');
#                $d.width(600); $d.height(400);
#                $d.jgraph = jQuery.extend({}, jgraph);
#                $d.jgraph.create($d, {nodeSize: 2.000000,
#                                      edgeSize: 0.250000,
#                                      defaultNodeColor: '0x5bc0de',
#                                      defaultEdgeColor: '0xaaaaaa',
#                                      shader: 'basic',
#                                      z: 100,
#                                      runOptimization: true,
#                                      directed: true,
#                                      showSave: false});
#                $d.jgraph.draw({
#     "edges": [
#         { "size": 5, "source": "tracer", "target": "soldier76" },
#         { "size": 2, "source": "soldier76", "target": "roadhog" },
#         { "size": 2, "source": "tracer", "target": "roadhog" },
#         { "size": 2, "source": "genji", "target": "ana" },
#         { "size": 2, "source": "widowmaker", "target": "genji" },
#         { "size": 2, "source": "widowmaker", "target": "ana" },
#         { "size": 2, "source": "zenyatta", "target": "mercy" },
#         { "size": 2, "source": "zenyatta", "target": "ana" },
#         { "size": 2, "source": "mercy", "target": "ana" },
#         { "size": 3, "source": "soldier76", "target": "genji" },
#         { "size": 2, "source": "tracer", "target": "genji" },
#         { "size": 1, "source": "torbjorn", "target": "soldier76" },
#         { "size": 1, "source": "tracer", "target": "torbjorn" },
#         { "size": 1, "source": "soldier76", "target": "dva" },
#         { "size": 1, "source": "genji", "target": "dva" },
#         { "size": 47, "source": "tracer", "target": "soldier76" },
#         { "size": 8, "source": "soldier76", "target": "roadhog" },
#         { "size": 6, "source": "tracer", "target": "roadhog" },
#         { "size": 4, "source": "genji", "target": "ana" },
#         { "size": 3, "source": "widowmaker", "target": "genji" },
#         { "size": 5, "source": "widowmaker", "target": "ana" },
#         { "size": 2, "source": "zenyatta", "target": "mercy" },
#         { "size": 2, "source": "zenyatta", "target": "ana" },
#         { "size": 4, "source": "mercy", "target": "ana" },
#         { "size": 31, "source": "soldier76", "target": "genji" },
#         { "size": 29, "source": "tracer", "target": "genji" },
#         { "size": 1, "source": "torbjorn", "target": "soldier76" },
#         { "size": 1, "source": "tracer", "target": "torbjorn" },
#         { "size": 2, "source": "soldier76", "target": "dva" },
#         { "size": 2, "source": "genji", "target": "dva" },
#         { "size": 11, "source": "mccree", "target": "genji" },
#         { "size": 1, "source": "reinhardt", "target": "mccree" },
#         { "size": 1, "source": "reinhardt", "target": "genji" },
#         { "size": 17, "source": "tracer", "target": "mccree" },
#         { "size": 3, "source": "reaper", "target": "mccree" },
#         { "size": 2, "source": "tracer", "target": "reaper" },
#         { "size": 20, "source": "soldier76", "target": "mccree" },
#         { "size": 6, "source": "zarya", "target": "roadhog" },
#         { "size": 10, "source": "zarya", "target": "soldier76" },
#         { "size": 4, "source": "soldier76", "target": "ana" },
#         { "size": 1, "source": "mccree", "target": "ana" },
#         { "size": 3, "source": "zarya", "target": "mccree" },
#         { "size": 2, "source": "winston", "target": "soldier76" },
#         { "size": 6, "source": "zarya", "target": "winston" },
#         { "size": 1, "source": "widowmaker", "target": "soldier76" },
#         { "size": 1, "source": "widowmaker", "target": "tracer" },
#         { "size": 2, "source": "mei", "target": "genji" },
#         { "size": 2, "source": "tracer", "target": "mei" },
#         { "size": 2, "source": "roadhog", "target": "genji" },
#         { "size": 3, "source": "zarya", "target": "ana" },
#         { "size": 3, "source": "zarya", "target": "genji" },
#         { "size": 1, "source": "roadhog", "target": "reaper" },
#         { "size": 3, "source": "roadhog", "target": "pharah" },
#         { "size": 1, "source": "reaper", "target": "pharah" },
#         { "size": 1, "source": "zarya", "target": "reinhardt" },
#         { "size": 1, "source": "soldier76", "target": "reinhardt" },
#         { "size": 2, "source": "roadhog", "target": "ana" },
#         { "size": 2, "source": "widowmaker", "target": "roadhog" },
#         { "size": 1, "source": "zenyatta", "target": "tracer" },
#         { "size": 1, "source": "zenyatta", "target": "soldier76" },
#         { "size": 3, "source": "tracer", "target": "ana" },
#         { "size": 5, "source": "zarya", "target": "tracer" },
#         { "size": 7, "source": "winston", "target": "roadhog" },
#         { "size": 2, "source": "soldier76", "target": "mercy" },
#         { "size": 3, "source": "pharah", "target": "genji" },
#         { "size": 2, "source": "zarya", "target": "dva" },
#         { "size": 1, "source": "pharah", "target": "dva" },
#         { "size": 1, "source": "zarya", "target": "pharah" },
#         { "size": 1, "source": "sombra", "target": "pharah" },
#         { "size": 1, "source": "sombra", "target": "roadhog" },
#         { "size": 2, "source": "tracer", "target": "pharah" },
#         { "size": 3, "source": "winston", "target": "reinhardt" },
#         { "size": 3, "source": "roadhog", "target": "reinhardt" },
#         { "size": 1, "source": "reaper", "target": "genji" },
#         { "size": 3, "source": "roadhog", "target": "dva" },
#         { "size": 2, "source": "lucio", "target": "dva" },
#         { "size": 2, "source": "roadhog", "target": "lucio" },
#         { "size": 37, "source": "tracer", "target": "soldier76" },
#         { "size": 21, "source": "soldier76", "target": "genji" },
#         { "size": 19, "source": "tracer", "target": "genji" },
#         { "size": 1, "source": "mccree", "target": "genji" },
#         { "size": 7, "source": "tracer", "target": "mccree" },
#         { "size": 10, "source": "soldier76", "target": "mccree" },
#         { "size": 27, "source": "tracer", "target": "soldier76" },
#         { "size": 11, "source": "soldier76", "target": "genji" },
#         { "size": 9, "source": "tracer", "target": "genji" },
#         { "size": 17, "source": "tracer", "target": "soldier76" },
#         { "size": 1, "source": "soldier76", "target": "genji" }
#     ],
#     "nodes": {
#         "ana": { "color": "0x37d03a", "size": 2.0 },
#         "bastion": { "color": "0xaaffaa", "size": 2.0 },
#         "dva": { "color": "0x41f2b5", "size": 2.0 },
#         "genji": { "color": "0xffaaaa", "size": 2.0 },
#         "hanzo": { "color": "0xaaffaa", "size": 2.0 },
#         "junkrat": { "color": "0xaaffaa", "size": 2.0 },
#         "lucio": { "color": "0x37d03a", "size": 2.0 },
#         "mccree": { "color": "0xffaaaa", "size": 2.0 },
#         "mei": { "color": "0xaaffaa", "size": 2.0 },
#         "mercy": { "color": "0x37d03a", "size": 2.0 },
#         "orisa": { "color": "0x41f2b5", "size": 2.0 },
#         "pharah": { "color": "0xffaaaa", "size": 2.0 },
#         "reaper": { "color": "0xffaaaa", "size": 2.0 },
#         "reinhardt": { "color": "0x41f2b5", "size": 2.0 },
#         "roadhog": { "color": "0x41f2b5", "size": 2.0 },
#         "soldier76": { "color": "0xffaaaa", "size": 2.0 },
#         "sombra": { "color": "0xffaaaa", "size": 2.0 },
#         "symmetra": { "color": "0x37d03a", "size": 2.0 },
#         "torbjorn": { "color": "0xaaffaa", "size": 2.0 },
#         "tracer": { "color": "0xffaaaa", "size": 2.0 },
#         "widowmaker": { "color": "0xaaffaa", "size": 2.0 },
#         "winston": { "color": "0x41f2b5", "size": 2.0 },
#         "zarya": { "color": "0x41f2b5", "size": 2.0 },
